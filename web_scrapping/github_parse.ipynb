# %% [markdown]
# репозитории

# %%
import github3
import requests

with open("key_gh.txt", "r") as fil:
    key = fil.readline()
github = github3.login(token=key)

# Получаем список репозиториев пользователя (например, текущего)
user = github.user(username="Leousov")

# repositories = user.repositories()

url = user.repos_url
res = requests.get(url) 

with open('res_gh.json', 'w') as file_:
    file_.write(str(res.json()))
# # Печатаем имена репозиториев
# for repository in repositories:
#     print(repository.name)

# %%
res.json()
# Out:
# [{'id': 1067888293,
#   'node_id': 'R_kgDOP6aupQ',
#   'name': '2_course',
#   'full_name': 'Leousov/2_course',
#   'private': False,
#   'owner': {'login': 'Leousov',
#    'id': 60581287,
#    'node_id': 'MDQ6VXNlcjYwNTgxMjg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60581287?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leousov',
#    'html_url': 'https://github.com/Leousov',
#    'followers_url': 'https://api.github.com/users/Leousov/followers',
#    'following_url': 'https://api.github.com/users/Leousov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Leousov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Leousov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Leousov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Leousov/orgs',
#    'repos_url': 'https://api.github.com/users/Leousov/repos',
# ...
